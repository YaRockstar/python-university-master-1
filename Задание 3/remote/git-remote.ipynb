# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git clone.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git remote add.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git remote -v.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git remote show.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git remote set url.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git add.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git commit and git push.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git diff.png"))

from IPython.display import Image, display
display(Image(filename="./screenshots/git difftool.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git fetch and git pull.png"))

from IPython.display import Image, display
display(Image(filename="./screenshots/git pull origin.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git push.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git push origin --delete.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git branch -m.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git branch origin new branch.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git tag.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git tag delete.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git log.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git reset and git push -f.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git branch -r.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git remote upstream.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/share.png"))

# %%
from IPython.display import Image, display
display(Image(filename="./screenshots/git branch -r.png"))
